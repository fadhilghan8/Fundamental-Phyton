# %%
# Praktek matematika tambah
print(10*2+5) # fungsi matematika
print("Semua Bisa Belajar Phyton")
# Out:
# 25
# Semua Bisa Belajar Phyton

# %% [markdown]
# ### Printing Data Type

# %%
# Tipe data Boolean, tipe yang memiliki dua nilai yaitu benar (true) yang bernilai 1 atau salah (false) yang bernilai 0.
print(True)

# tipe data String, String adalah kumpulan alfabet, kata, atau karakter lain.
print("Aku mahir Phyton")
print("Let's Go to Korea")

# tipe data interger, 
#Tipe bilangan bulat (Integer) adalah tipe data numerik yang biasa digunakan apabila bertemu dengan bilangan bulat. Bilangan ini juga mengenal nilai positif dan negatif 
print(20)

# tipe data float, Menyatakan bilangan yang mempunyai koma
print(2.22)

# tipe data list
print ([1,2,3,4,5])
print(["satuu","dua","tiga"])

# tipe data dictionary
print ({"nama":"Budi", 'umur':20})

#tipe data dictionary dimasukkan dalam variabel biodata
biodata = {"nama":"Fadhil", 'umur':20} # proses inisialisasi variabel biodata
print(biodata) # proses pencetakan variabel biodata yang berisi tipe data dictionary
type(biodata) # fungsi untuk mengecek jenis tipe data. akan tampil <classs 'dict'
# Out:
# True
# Aku mahir Phyton
# Let's Go to Korea
# 20
# 2.22
# [1, 2, 3, 4, 5]
# ['satuu', 'dua', 'tiga']
# {'nama': 'Budi', 'umur': 20}
# {'nama': 'Fadhil', 'umur': 20}
# dict

# %% [markdown]
# ### Praktek
# ##### printing data type menggunakan variable

# %%
# ketikkan kode dibawah ini pada Code Editor
var_string="Ayo belajar Phyton"
var_int=10
var_float=22.7
var_list=[1,2,3,4]
var_tuple=("satu","dua","tiga")
var_dict={"nama":"Fadhil", 'umur':20}

print(var_string)
print(var_int)
print(var_list)
print(var_tuple)
print(var_dict)
# Out:
# Ayo belajar Phyton
# 10
# [1, 2, 3, 4]
# ('satu', 'dua', 'tiga')
# {'nama': 'Fadhil', 'umur': 20}

# %%
# tamabahkan code dibawah ini untuk mengetahui type data dari suatu value di variabel
print(type(var_string))
print(type(var_int))
print(type(var_list))
print(type(var_tuple))
print(type(var_dict))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %% [markdown]
# ## IF Statement

# %% [markdown]
# #### Penggunaan IF sebenarnya adalah sebuah statement untuk menentukan keputusan mana yang akan diambil berdasarkan suatu kondisi yang ditentukan oleh pembuat program

# %%
# Cobalah ketikkan kode seperti dibawah ini

i = 15 # inisialisasi variable i yang memiliki nilai 10

if(i==15): # pengecekan nilai i apakah sama dengan 10
    print("ini adalah angka 15") # jika TRUE maka akan mencetak kalimat ini
# Out:
# ini adalah angka 15

# %% [markdown]
# ## IF....ELSE....

# %% [markdown]
# #### Cobalah ketikkan kode seperti ini

# %%
i = 15 #inisialisasi variable i yang memiliki nilai 15

if(i==10): # pengecekan nilai i apakah sama dengan 15
    print("ini adalah angka 15") # jika TRUE maka akan mencetak kalimat ini
else:
    print("bukan angka 15") #jika FALSE akan mencetak kalimat ini
# Out:
# bukan angka 15

# %% [markdown]
# ## IF....ELIF....ELSE....

# %%
i=7

if(i==7):
    print("ini adalah angka 7")
elif(i>7):
    print("lebih besar dari 7")
else:
    print("lebih kecil dari 5")
# Out:
# ini adalah angka 7

# %% [markdown]
# ### NESTED IF
# Fungsi IF sendiri bisa digunakan secara bertingkat. Atau dilakukan pengecekan lebih dari 1 statement di dalamnya

# %%
i=3
if(i<7):
    print("nilai i kurang dari 7")
    if(i<4):
        print("nilai i kurang dari 7 dan kurang dari 4")
    else:
        print("nilai i kurang dari 7 tetapi lebih dari 4")
# Out:
# nilai i kurang dari 7
# nilai i kurang dari 7 dan kurang dari 4

# %% [markdown]
# #### Data Science tak akan lepas dari Matematika . Pada track phyton kali ini kita juga belajar berbagai macam operator matematika dalam phyton yang dapat membantu dalam belajar Data Science.
# #### Pada sesi kali ini, operator yang disajikan adalah operator operator dasar dan logika pada matematika.
# #### Pada dasarnya, setiap bahasa pemrogramman memiliki operasi pengolahan angka dan pembanding
#
# operator yang akan kita bahas kali ini adalah:
#
# Nama operator | Logo operator
#
# - Tambah +
# - kurang -
# - pembagi /
# - perkalian *
# - modulus %
# - kurang dari <
# - lebih dari >
# - kurang dari sama dengan <=
# - lebih dari sama dengan >=
# - sama dengan =

# %% [markdown]
# #### Praktek Operasi Matematika
#
# Pada praktek ini kita akan mencoba semua operator matematika
#
# Praktek pada sisi kali ini kita akan menekankan bagaimana menggunakan operator langsung diimplementasikan dengan variable

# %%
a=20
b=10
selisih = a-b
jumlah = a+b
kali = a*b
bagi = a/b
print("Hasil penjumlahan a dan b adalah", jumlah)
print("Selisih a dan b adalah", selisih)
print("Perkalian a dan b adalah", kali)
print("Pembagian a dan b adalah", bagi)
# Out:
# Hasil penjumlahan a dan b adalah 30
# Selisih a dan b adalah 10
# Perkalian a dan b adalah 200
# Pembagian a dan b adalah 2.0

# %% [markdown]
# #### Operasi modulus
# Modulus memang jarang dipakai namun, dibeberapa kasus modulus sangat berguna untuk mempercepat proses perhitungan. Modulus sendiri merupakan fungsi yang akan menghitung sisa dari hasil pembagian

# %%
c=20
d=5

modulus=c%d
print("Hasil modulus",modulus)
# Out:
# Hasil modulus 0

# %%
angka=5

if(angka%2==0):
    print("angka termasuk bilangan genap")
else:
    print("angka termasuk bilangan ganjil")
# Out:
# angka termasuk bilangan ganjil

# %% [markdown]
# #### Looping
# Perulangan atayu looping merupakan salah satu elemen fungsi yang bisa dikatakan sangat menunjang untuk kebutuhan programming dan data science
#
# Tidak mungkin jika kita harus memproses 1000x eksekusi code, kita harus menulis ulang kode tersebut sebanyak 1000x juga.
#
# Selain tidak bersifat scalable, efisiensi akan mempengaruhi performa program yang kita buat. Seperti pada umumnya phyton juga memiliki fungsi for dan while untuk melakukan looping. Logikanya hampir sama, namun hanya berbeda dalam penulisannya jika anda sudah terbiasa dengan C atau Java.

# %% [markdown]
# #### While
# Struktur while pada phyton tidak berbeda jauh dengan bahasa pemrogramman lainnya. Lebih sederhananya struktur penulisan phyton membuat dia lebih mudah dibaca

# %%
k = 0 #nilai awal k = 0

while k<6: #ketika k kurang dari 6 lakukan perulangan, jika tidak stop perulangan
    print("Ini adalah perulangan ke -",k) # lakukan perintah ini ketika perulangan
    k=k+1 # setiap kali diakhir perunlangan update nilai dengan ditambah 1
# Out:
# Ini adalah perulangan ke - 0
# Ini adalah perulangan ke - 1
# Ini adalah perulangan ke - 2
# Ini adalah perulangan ke - 3
# Ini adalah perulangan ke - 4
# Ini adalah perulangan ke - 5

# %% [markdown]
# ### for (1)
# Struktur looping pada phyton berbeda dengan struktur for pada umumnya. Pastikan untuk diperhatikan dengan baik

# %%
for i in range (2, 7): # perulangan for sebagai inisialisasi  dari angka 1 hingga angka yang lebih kecil daripada 7
    print("ini adalah perulangan ke -", i) # perintah jika looping akan tetap berjalan
# Out:
# ini adalah perulangan ke - 2
# ini adalah perulangan ke - 3
# ini adalah perulangan ke - 4
# ini adalah perulangan ke - 5
# ini adalah perulangan ke - 6

# %% [markdown]
# #### for (2) with acces element
# Keunikan lain darri looping dengan phyton adalah selain bahasa yang mudah dimengerti dalam looping, kita juga bisa mengakses elemen yang terdapat pada sebuah list. Berikut contohnya :

# %%
count=[1,2,3,4,5] # elemen list

for number in count: # looping untuk menampilkan semua elemen pada count
    print("ini adalah elemen count :", number) # menampilkan elemen list pada count
# Out:
# ini adalah elemen count : 1
# ini adalah elemen count : 2
# ini adalah elemen count : 3
# ini adalah elemen count : 4
# ini adalah elemen count : 5

# %%
for i in range (3,8):
    if(i%2==0):
        print("Angka genap",i)
    else:
        print("Angka ganjil",i)
# Out:
# Angka ganjil 3
# Angka genap 4
# Angka ganjil 5
# Angka genap 6
# Angka ganjil 7

# %% [markdown]
# Pada pembuatan program yang kompleks dan memiliki banyak fitur, kita diharuskan menggunakan fungsi. Kenapa memangnya kalau  tidak menggunakan fungsi? Bisa jadi kita akan kerepotan menulis kode programnya, karena banyak yang harus ditulis dan kode akan menjadi sulit dibaca dan dirawat(maintenance). Dengan fungsi kita dapat memecah program besar menjadi sub program yang lebih sederhana. Masing masing fitur pada program dapat kita buat dalam satu fungsi. Pada saat kita membutuhkan fitur tersebut, kita tinggal panggil fungsinya saja.

# %% [markdown]
# #### Membuat fungsi sendiri
# fungsi pada phyton, dibuat dengan kata kunci def kemudian diikuti dengan nama fungsinya.

# %%
def nama_fungsi():
    print("ini fungsi")
nama_fungsi() #memanggil fungsi yang telah kita buat
# Out:
# ini fungsi

# %%
# contoh kedua
# membuat fungsi
def basa_basi():
    print("Hai, lagi ngapain nich?")
    
## pemanggil fungsi
basa_basi()
# Out:
# Hai, lagi ngapain nich?

# %% [markdown]
# ### Parameter pada fungsi
# Sekarang, bagaimana kalau kita ingin memberikan input nilai kedalam fungsi? Kita bisa menggunakan parameter. Parameter adalah variabel yang menampung nilai untuk diproses kedalam satu fungsi

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "data:image/png;base64,...")
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# Pada contoh kali ini untuk mempermudah pembelajaran telah disediakan rumusan matematika untuk menghitung luas segitiga. Berikut contoh kodenya:

# %%
def luas_segitiga(alas, tinggi): #alas dan tinggi merupakan parameter yang masuk
    luas = (alas * tinggi) / 2
    print("luas segitiga: %f" % luas);
    
# pemanggilan fungsi
# 4 dan 6 merupakan parameter yang diinputkan kedalam fungsi luas segitiga
luas_segitiga(4, 6)
# Out:
# luas segitiga: 12.000000

# %% [markdown]
# ### Fungsi dengan Return Value
# Fungsi yang tidak mengembalikan nilai biasanya disebut dengan prosedur. Namun, kadang kita butuh hasil proses dari fungsi untuk digunakan pada proses berikutnya. Maka fungsi harus mengembalikan nilai dari hasil pemrosesannya.
# Cara mengembalikan nilai adalah menggunakan kata kunci return lalu diikuti dengan nilai atau variabel yang akan dikembalikan

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "data:image/png;base64,...")
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# Meneruskan kembali di poin sebelumnya. Untuk fungsi luas segitiga yang sudah dibuat, mari tambahkan return value sehingga menjadi seperti ini:

# %%
def luas_segitiga(alas, tinggi): #alas dan tinggi merupakan parameter yang masuk
    luas = (alas * tinggi) / 2
    return luas

#pemanggilan fungsi
# 4 dan 6 merupakan parameter yang diinputkan kedalam fungsi luas segitiga
print("luas segitiga: %d" % luas_segitiga(4, 6))
# Out:
# luas segitiga: 12

# %% [markdown]
# ### Membaca file CSV dengan menggunakan PANDAS
# Pandas merupakan library yang sering digunakan untuk aplikasi dan implementasi data science.

# %%
import pandas as pd

table = pd.read_csv("penduduk_gender_head.csv")
table.head()
print(table)
# Out:
#     TAHUN         NAMA PROVINSI NAMA KABUPATEN/KOTA NAMA KECAMATAN  \
# 0    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT         GAMBIR
# 1    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT         GAMBIR
# 2    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT         GAMBIR
# 3    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT         GAMBIR
# 4    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT         GAMBIR
# 5    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT         GAMBIR
# 6    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT    SAWAH BESAR
# 7    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT    SAWAH BESAR
# 8    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT    SAWAH BESAR
# 9    2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT    SAWAH BESAR
# 10   2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT    SAWAH BESAR
# 11   2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT      KEMAYORAN
# 12   2013  PROVINSI DKI JAKARTA       JAKARTA PUSAT      KEMAYORAN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

table = pd.read_csv("penduduk_gender_head.csv")
table.head()
x_label = table['NAMA KELURAHAN']
plt.bar(x=np.arange(len(x_label)),height=table['LAKI-LAKI WNI'])
plt.show()
